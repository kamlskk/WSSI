# %% [markdown]
# <a href="https://colab.research.google.com/github/kamlskk/WSSI/blob/main/Prolog2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Zadania końcowe z **Prologa**
#
# ###Poniżej znajdują się rozwiązania zadań z Prologa na **Wstęp do Systemów Sztucznej Inteligencji** uzupełnione o dodatkowe elementy

# %% [markdown]
# # Zadanie 1: Drzewo genealogiczne

# %%
% Fakty dotyczące rodziców
ojciec(jan, elzbieta).
ojciec(jan, teresa).
ojciec(wladyslaw, stanislaw).
ojciec(jozef, maria).
ojciec(kazimierz, antoni).
ojciec(zygmunt, barbara).
ojciec(leopold, krzysztof).
ojciec(feliks, maciej).
ojciec(bogdan, wojciech).
ojciec(czeslaw, zofia).
ojciec(mieczyslaw, tadeusz).
ojciec(aureliusz, julia).
ojciec(stanislaw, grzegorz).
ojciec(stanislaw, tomasz).
ojciec(antoni, pawel).
ojciec(krzysztof, monika).
ojciec(krzysztof, martyna).
ojciec(krzysztof, milena).
ojciec(maciej, katarzyna).
ojciec(wojciech, marek).
ojciec(tadeusz, natalia).
ojciec(pawel, emil).
ojciec(pawel, piotr).
ojciec(pawel, anna).
ojciec(grzegorz, wiktoria).
ojciec(grzegorz, szymon).
ojciec(tomasz, jakub).
ojciec(tomasz, emilia).
ojciec(marek, oliwia).
ojciec(marek, lena).
ojciec(marek, zofia).

matka(helena, elzbieta).
matka(helena, teresa).
matka(rozalia, stanislaw).
matka(jadwiga, maria).
matka(helena, antoni).
matka(klementyna, barbara).
matka(irena, krzysztof).
matka(emilia, maciej).
matka(gertruda, wojciech).
matka(aniela, zofia).
matka(teodora, tadeusz).
matka(eugenia, julia).
matka(maria, grzegorz).
matka(maria, tomasz).
matka(barbara, pawel).
matka(elzbieta, monika).
matka(elzbieta, martyna).
matka(elzbieta, milena).
matka(teresa, katarzyna).
matka(zofia, marek).
matka(julia, natalia).
matka(monika, emil).
matka(monika, piotr).
matka(monika, anna).
matka(martyna, wiktoria).
matka(martyna, szymon).
matka(natalia, jakub).
matka(natalia, emilia).
matka(katarzyna, oliwia).
matka(katarzyna, lena).
matka(katarzyna, zofia).

% Fakty - małżeństwa
malzenstwo(jan, helena).
malzenstwo(wladyslaw, rozalia).
malzenstwo(jozef, jadwiga).
malzenstwo(kazimierz, helena).
malzenstwo(zygmunt, klementyna).
malzenstwo(leopold, irena).
malzenstwo(feliks, emilia).
malzenstwo(bogdan, gertruda).
malzenstwo(czeslaw, aniela).
malzenstwo(mieczyslaw, teodora).
malzenstwo(aureliusz, eugenia).

malzenstwo(stanislaw, maria).
malzenstwo(antoni, barbara).
malzenstwo(elzbieta, krzysztof).
malzenstwo(teresa, maciej).
malzenstwo(wojciech, zofia).
malzenstwo(tadeusz, julia).

malzenstwo(monika, pawel).
malzenstwo(martyna, grzegorz).
malzenstwo(katarzyna, marek).
malzenstwo(tomasz, natalia).

% Fakty dotyczące płci
mezczyzna(jan). mezczyzna(wladyslaw). mezczyzna(jozef). mezczyzna(kazimierz). mezczyzna(zygmunt).
mezczyzna(leopold). mezczyzna(feliks). mezczyzna(bogdan). mezczyzna(czeslaw). mezczyzna(mieczyslaw).
mezczyzna(aureliusz). mezczyzna(stanislaw). mezczyzna(antoni). mezczyzna(krzysztof). mezczyzna(maciej).
mezczyzna(wojciech). mezczyzna(tadeusz). mezczyzna(pawel). mezczyzna(grzegorz). mezczyzna(tomasz).
mezczyzna(marek). mezczyzna(emil). mezczyzna(piotr). mezczyzna(szymon). mezczyzna(jakub).

kobieta(helena). kobieta(rozalia). kobieta(jadwiga). kobieta(klementyna). kobieta(irena).
kobieta(emilia). kobieta(gertruda). kobieta(aniela). kobieta(teodora). kobieta(eugenia).
kobieta(maria). kobieta(barbara). kobieta(elzbieta). kobieta(teresa). kobieta(zofia).
kobieta(julia). kobieta(monika). kobieta(martyna). kobieta(milena). kobieta(katarzyna).
kobieta(natalia). kobieta(anna). kobieta(wiktoria). kobieta(oliwia). kobieta(lena).

% Reguły podstawowe
przodek(X, Y) :- ojciec(X, Y).
przodek(X, Y) :- matka(X, Y).
przodek(X, Y) :- ojciec(X, Z), przodek(Z, Y).
przodek(X, Y) :- matka(X, Z), przodek(Z, Y).

brat(X, Y) :- mezczyzna(X), ojciec(Z, X), ojciec(Z, Y), X \= Y.
brat(X, Y) :- mezczyzna(X), matka(Z, X), matka(Z, Y), X \= Y.

siostra(X, Y) :- kobieta(X), ojciec(Z, X), ojciec(Z, Y), X \= Y.
siostra(X, Y) :- kobieta(X), matka(Z, X), matka(Z, Y), X \= Y.

kuzyn(X, Y) :-
    ojciec(A, X), ojciec(B, Y), brat(A, B), X \= Y.
kuzyn(X, Y) :-
    matka(A, X), matka(B, Y), siostra(A, B), X \= Y.
kuzyn(X, Y) :-
    ojciec(A, X), matka(B, Y), brat(A, B), X \= Y.
kuzyn(X, Y) :-
    matka(A, X), ojciec(B, Y), siostra(A, B), X \= Y.

% ELEMENTY DODATKOWE
% 1. Dziadek i Babcia
dziadek(X, Y) :- ojciec(X, Z), (ojciec(Z, Y) ; matka(Z, Y)).
babcia(X, Y) :- matka(X, Z), (ojciec(Z, Y) ; matka(Z, Y)).

% 2. Wnuk i Wnuczka
wnuk(X, Y) :- mezczyzna(X), (dziadek(Y, X) ; babcia(Y, X)).
wnuczka(X, Y) :- kobieta(X), (dziadek(Y, X) ; babcia(Y, X)).

% 3. Teść i Teściowa
tesc(X, Y) :- ojciec(X, Z), malzenstwo(Z, Y).
tesciowa(X, Y) :- matka(X, Z), malzenstwo(Z, Y).

% 5. Wujek i Ciotka
wujek(X, Y) :- mezczyzna(X), (ojciec(Z, Y) ; matka(Z, Y)), brat(X, Z).
ciotka(X, Y) :- kobieta(X), (ojciec(Z, Y) ; matka(Z, Y)), siostra(X, Z).

% 7. Potomek
potomek(X, Y) :- przodek(Y, X).

# %% [markdown]
# #**Przykładowe zapytania**

# %%
% Zapytania przykładowe
% 1. przodek
% ?- przodek(jan, milena).+

% 2. brat
% ?- brat(grzegorz, tomasz).+

% 3. siostra
% ?- siostra(elzbieta, teresa).+

% 4. kuzyn
% ?- kuzyn(szymon, jakub).+

% 5. dziadek
% ?- dziadek(kazimierz, pawel).+

% 6. babcia
% ?- babcia(barbara, anna).+

% 7. wnuk
% ?- wnuk(jakub, stanislaw).+

% 8. wnuczka
% ?- wnuczka(milena, helena).+

% 9. tesc
% ?- tesc(jan, maciej). +

% 10. tesciowa
% ?- tesciowa(helena, maciej). +

% 11. wujek
% ?- wujek(tomasz, szymon).

% 12. ciotka
% ?- ciotka(monika, wiktoria).+

% 13. potomek
% ?- potomek(monika, jan).+

# %% [markdown]
# #**Zapytania przykładowe**
# ##**1. Przodek**
# ```
# ?- przodek(jan, milena).
# ```
# ###**Wynik:**
# ```
# True
# ```
# ##**2. Brat**
# ```
# ?- brat(grzegorz, tomasz).
# ```
# ###**Wynik:**
# ```
# True
# ```
# ##**3. Siostra**
# ```
# ?- siostra(elzbieta, teresa).
# ```
# ###**Wynik:**
# ```
# True
# ```
# ##**4. Kuzyn**
# ```
# ?- kuzyn(szymon, jakub).
# ```
# ###**Wynik:**
# ```
# True
# ```
# ##**5. Dziadek**
# ```
# ?- dziadek(kazimierz, pawel).
# ```
# ###**Wynik:**
# ```
# True
# ```
# ##**6. Babcia**
# ```
# ?- babcia(barbara, anna).
# ```
# ###**Wynik:**
# ```
# True
# ```
# ##**7. Wnuk**
# ```
# ?- wnuk(jakub, stanislaw).
# ```
# ###**Wynik:**
# ```
# True
# ```
# ##**8. Wnuczka**
# ```
# ?- wnuczka(milena, helena).
# ```
# ###**Wynik:**
# ```
# True
# ```
# ##**9. Tesc**
# ```
# ?- tesc(jan, maciej).
# ```
# ###**Wynik:**
# ```
# True
# ```
# ##**10. Tesciowa**
# ```
# ?- tesciowa(helena, maciej).
# ```
# ###**Wynik:**
# ```
# True
# ```
# ##**11. Wujek**
# ```
# ?- wujek(tomasz, szymon).
# ```
# ###**Wynik:**
# ```
# True
# ```
# ##**12. Ciotka**
# ```
# ?- ciotka(monika, wiktoria).
# ```
# ###**Wynik:**
# ```
# True
# ```
# ##**13. Potomek**
# ```
# ?- potomek(monika, jan).
# ```
# ###**Wynik:**
# ```
# True
# ```

# %% [markdown]
# #**Wytłumaczenie:**

# %% [markdown]
# ##**1. Przodek (jan, milena):**
# ```
# przodek(X, Y) :- ojciec(X, Y).
# przodek(X, Y) :- ojciec(X, Z), przodek(Z, Y).
# ```
# ###**Opis:**
#
# - Pierwsza część reguły mówi: `jan` jest przodkiem `milena`, jeśli `jan` jest jej ojcem. To jednak nie zachodzi bezpośrednio, ponieważ ojcem `milena` jest `grzegorz`.
# -Druga część reguły działa rekursywnie: sprawdza, czy `jan` jest ojcem kogoś (w tym przypadku `elzbieta`), kto jest przodkiem `milena`.
# -`jan` → ojciec `elzbieta`, a `elzbieta` → matka `milena`.
# - W ten sposób `jan` zostaje uznany za przodka `milena`.
#
# ## **2. Brat (grzegorz, tomasz).**
# ```
#     brat(X, Y) :- mezczyzna(X), ojciec(Z, X), ojciec(Z, Y), X \= Y.
#     brat(X, Y) :- mezczyzna(X), matka(Z, X), matka(Z, Y), X \= Y.
# ```
# ###**Opis:**
# - Reguła najpierw sprawdza, czy `grzegorz` i `tomasz` mają wspólnego ojca. Obaj mają ojca `stanislaw`.
# - Następnie sprawdza, czy mają wspólną matkę. Obaj mają matkę `maria`.
# - `grzegorz` jest mężczyzną (`mezczyzna(grzegorz)` zwraca `true`), a `grzegorz \= tomasz`.
# - Wszystkie warunki są spełnione, więc `brat(grzegorz, tomasz)` zwraca `true`.
#
# ## **3. Siostra (elzbieta, teresa).**
# ```
#     siostra(X, Y) :- kobieta(X), ojciec(Z, X), ojciec(Z, Y), X \= Y.
#     siostra(X, Y) :- kobieta(X), matka(Z, X), matka(Z, Y), X \= Y.
# ```
# ###**Opis:**
# - Reguła najpierw sprawdza, czy `elzbieta` i `teresa` mają wspólnego ojca. Obie mają ojca `jan`.
# - Następnie sprawdza, czy mają wspólną matkę. Obie mają matkę `helena`.
# - `elzbieta` jest kobietą (`kobieta(elzbieta)` zwraca `true`), a `elzbieta \= teresa`.
# - Wszystkie warunki są spełnione, więc `siostra(elzbieta, teresa)` zwraca `true`.
#
# ## **4. Kuzyn (szymon, jakub).**
# ```
#     kuzyn(X, Y) :- ojciec(A, X), ojciec(B, Y), brat(A, B), X \= Y.
# ```
# ###**Opis:**
# - Ojcem `szymon` jest `grzegorz`, a ojcem `jakub` jest `tomasz`.
# - Reguła sprawdza, czy `grzegorz` i `tomasz` są braćmi. Wynik dla `brat(grzegorz, tomasz)` zwrócił `true`.
# - `szymon` i `jakub` to różne osoby ` (szymon \= jakub)`
# - Wszystkie warunki są spełnione, więc `kuzyn(szymon, jakub)` zwraca `true`.
#
# ## **5. Dziadek (kazimierz, pawel).**
# ```
#     dziadek(X, Y) :- ojciec(X, Z), (ojciec(Z, Y) ; matka(Z, Y)).
# ```
# #**Opis:**
# - Zapytanie sprawdza, czy `kazimierz` jest dziadkiem `pawel`.
# - Sprawdza, czy `kazimierz` jest ojcem kogoś (`antoni`), a ta osoba jest ojcem lub matką `pawel`. Okazuje się, że `kazimierz` jest ojcem `antoni`, a `antoni` jest ojcem `pawel`.
# - Ponieważ warunki są spełnione, wynik `dziadek(kazimierz, pawel)` zwraca `true`.
#
# ## **6. Babcia (barbara, anna).**
# ```
# babcia(X, Y) :- matka(X, Z), (ojciec(Z, Y) ; matka(Z, Y)).
# ```
# ###**Opis:**
# - Zapytanie sprawdza, czy `barbara` jest babcią `anna`.
# - Weryfikuje, czy `barbara` jest matką rodzica `anna`. Może to być zarówno ojciec, jak i matka anna.
# - Sprawdza, czy `barbara` jest matką `pawel` (fakt `matka(barbara, pawel)`).
# - Następnie sprawdza, czy pawel jest ojcem `anna` (fakt `ojciec(pawel, anna)`).
# - Oba warunki są spełnione, więc `barbara` jest babcią `anna`.
#
# ##**7. Wnuk (jakub, stanislaw).**
# ```
#     wnuk(X, Y) :- mezczyzna(X), (dziadek(Y, X) ; babcia(Y, X)).
# ```
# ###**Opis:**
#
# - Zapytanie sprawdza, czy `jakub` jest wnukiem `stanislaw`.
# - Sprawdza, czy `jakub` jest mężczyzną (`mezczyzna(jakub)`), a także czy `stanislaw` jest dziadkiem `jakub`. Okazuje się, że jest, ponieważ `stanislaw` jest ojcem `tomasz`, a `tomasz` jest ojcem `jakub`.
# - Więc wynik `wnuk(jakub, stanislaw)` zwraca `true`.
#
# ## **8. Wnuczka (milena, helena).**
# ```
# wnuczka(X, Y) :- kobieta(X), (dziadek(Y, X) ; babcia(Y, X)).
# ```
# ###**Opis:**
# - Zapytanie sprawdza, czy `milena` jest wnuczką `helena`.
# - Weryfikuje, czy `milena` jest kobietą i czy `helena` jest jej dziadkiem lub babcią.
# - `milena` jest kobietą (fakt `kobieta(milena)`).
# - Sprawdza, czy `helena` jest babcią `milena` za pomocą reguły `babcia/2`:
#   - `helena` jest matką `krzysztof` (fakt `matka(helena, krzysztof)`).
#   - `krzysztof` jest ojcem `milena` (fakt `ojciec(krzysztof, milena)`).
# - Oba warunki są spełnione, więc `milena` jest wnuczką `helena`.
#
# ## **9. Tesc (jan, maciej).**
#
# ```
#     tesc(X, Y) :- ojciec(X, Z), malzenstwo(Z, Y).
# ```
# ###**Opis:**
# - Zapytanie sprawdza, czy `jan` jest teściem `maciej`.
# - Sprawdza, czy `jan` jest ojcem kogoś (`elzbieta`), kto jest żoną `maciej`. Okazuje się, że jest (`malzenstwo(elzbieta, maciej)` zwróciło `true`).
# - Wiec wynik `tesc(jan, maciej)` zwraca `true`.
#
# ## **10. Tesciowa (helena, maciej).**
# ```
# tesciowa(X, Y) :- matka(X, Z), malzenstwo(Z, Y).
# ```
# ##**Opis:**
# - Zapytanie sprawdza, czy `helena` jest teściową `maciej`.
# - Weryfikuje, czy `helena` jest matką osoby, która jest w związku małżeńskim z `maciej`.
# - Sprawdza, czy `helena` jest matką `teresa` (`fakt matka(helena, teresa)`).
# - Następnie sprawdza, czy `teresa` i `maciej` są małżeństwem (fakt `malzenstwo(teresa, maciej)`).
# - Oba warunki są spełnione, więc `helena` jest teściową `maciej`.
#
# ## **11. Wujek (tomasz, szymon).**
# ```
# wujek(X, Y) :- mezczyzna(X), (ojciec(Z, Y) ; matka(Z, Y)), brat(X, Z).
# ```
# ##**Opis:**
# - Zapytanie sprawdza, czy `tomasz` jest wujkiem `szymon`.
# - Weryfikuje, czy `tomasz` jest mężczyzną, a następnie sprawdza, czy `tomasz` jest bratem rodzica `szymon`.
# - `tomasz` jest mężczyzną (`fakt mezczyzna(tomasz)`).
# - Sprawdza, czy `tomasz` jest bratem `grzegorz` (rodzica `szymon`) za pomocą reguły `brat/2`:
#   - `tomasz` i `grzegorz` mają tego samego ojca (`stanislaw`) oraz tę samą matkę (`maria`).
# - Następnie sprawdza, czy `grzegorz` jest ojcem `szymon` (fakt `ojciec(grzegorz, szymon)`).
# - Oba warunki są spełnione, więc `tomasz` jest wujkiem `szymon`.
#
# ## **12. Ciotka (monika, wiktoria).**
#
# ```
#     ciotka(X, Y) :- kobieta(X), (ojciec(Z, Y) ; matka(Z, Y)), siostra(X, Z).
# ```
# ###**Opis:**
# - Zapytanie sprawdza, czy `monika` jest ciotką `wiktoria`.
# - Sprawdza, czy `monika` jest kobietą, a następnie sprawdza, czy `monika` jest siostrą rodzica `wiktoria`. Okazuje się, że `monika` jest siostrą `martyna`, która jest matką `wiktoria`
# - Ponieważ warunki są spełnione, wynik `ciotka(monika, wiktoria)` zwraca `true`.
#
# ## **13. Potomek (monika, jan).**
# ```
# potomek(X, Y) :- przodek(Y, X).
# ```
# ###**Opis:**
#
# - Zapytanie sprawdza, czy `monika` jest potomkiem `jan`.
# - Sprawdza, czy `jan` jest przodkiem `moniki` za pomocą reguły `przodek/2`, odwracając jej argumenty.
# - Prolog weryfikuje, czy `jan` jest przodkiem `moniki`.
# - Wykorzystuje fakty dotyczące `ojciec` i `matka`, a także rekurencyjnie przeszukuje pokolenia:
#   - Z faktu `ojciec(jan, elzbieta)` wiadomo, że `jan` jest ojcem `elzbiety`.
#   - Z faktu `matka(elzbieta, monika)` wiadomo, że `elzbieta` jest matką `moniki`.
#   - Z tego wynika, że `jan` jest przodkiem `moniki`, więc `monika` jest potomkiem `jan`.

# %% [markdown]
# # Zadanie 2: System rezerwacji lotów

# %%
% Lotniska
lotnisko(warszawa).
lotnisko(krakow).
lotnisko(gdansk).
lotnisko(wroclaw).
lotnisko(pozen).
lotnisko(szczecin).
lotnisko(katowice).
lotnisko(rybnik).
lotnisko(lublin).
lotnisko(bialystok).
lotnisko(olsztyn).
lotnisko(rzeszow).

% Połączenia między lotniskami (lotnisko1, lotnisko2, koszt)
polaczenie(warszawa, krakow, 300).
polaczenie(krakow, warszawa, 300).
polaczenie(krakow, gdansk, 200).
polaczenie(gdansk, krakow, 200).
polaczenie(warszawa, gdansk, 500).
polaczenie(gdansk, warszawa, 500).
polaczenie(warszawa, wroclaw, 150).
polaczenie(wroclaw, warszawa, 150).
polaczenie(warszawa, pozen, 180).
polaczenie(pozen, warszawa, 180).
polaczenie(wroclaw, gdansk, 220).
polaczenie(gdansk, wroclaw, 220).
polaczenie(krakow, wroclaw, 250).
polaczenie(wroclaw, krakow, 250).
polaczenie(gdansk, pozen, 350).
polaczenie(pozen, gdansk, 350).
polaczenie(krakow, lublin, 350).
polaczenie(lublin, krakow, 350).
polaczenie(warszawa, bialystok, 280).
polaczenie(bialystok, warszawa, 280).
polaczenie(bialystok, krakow, 330).
polaczenie(krakow, bialystok, 330).
polaczenie(warszawa, katowice, 210).
polaczenie(katowice, warszawa, 210).
polaczenie(rybnik, katowice, 100).
polaczenie(katowice, rybnik, 100).
polaczenie(wroclaw, szczecin, 300).
polaczenie(szczecin, wroclaw, 300).
polaczenie(szczecin, gdansk, 420).
polaczenie(gdansk, szczecin, 420).
polaczenie(katowice, pozen, 230).
polaczenie(pozen, katowice, 230).
polaczenie(lublin, szczecin, 380).
polaczenie(szczecin, lublin, 380).
polaczenie(krakow, rybnik, 250).
polaczenie(rybnik, krakow, 250).
polaczenie(warszawa, szczecin, 420).
polaczenie(szczecin, warszawa, 420).
polaczenie(wroclaw, katowice, 160).
polaczenie(katowice, wroclaw, 160).
polaczenie(bialystok, wroclaw, 370).
polaczenie(wroclaw, bialystok, 370).
polaczenie(rybnik, wroclaw, 190).
polaczenie(wroclaw, rybnik, 190).
polaczenie(wroclaw, olsztyn, 200).
polaczenie(olsztyn, wroclaw, 200).
polaczenie(poznan, rzeszow, 450).
polaczenie(rzeszow, poznan, 450).
polaczenie(lublin, olsztyn, 380).
polaczenie(olsztyn, lublin, 380).
polaczenie(bialystok, olsztyn, 310).
polaczenie(olsztyn, bialystok, 310).
polaczenie(warszawa, rzeszow, 400).
polaczenie(rzeszow, warszawa, 400).
polaczenie(szczecin, poznan, 280).
polaczenie(poznan, szczecin, 280).
polaczenie(krakow, olsztyn, 370).
polaczenie(olsztyn, krakow, 370).

% Ceny biletów
cena_biletu(warszawa, krakow, 250).
cena_biletu(krakow, warszawa, 250).
cena_biletu(krakow, gdansk, 180).
cena_biletu(gdansk, krakow, 180).
cena_biletu(warszawa, gdansk, 460).
cena_biletu(gdansk, warszawa, 460).
cena_biletu(warszawa, wroclaw, 120).
cena_biletu(wroclaw, warszawa, 120).
cena_biletu(warszawa, pozen, 150).
cena_biletu(pozen, warszawa, 150).
cena_biletu(wroclaw, gdansk, 200).
cena_biletu(gdansk, wroclaw, 200).
cena_biletu(krakow, wroclaw, 230).
cena_biletu(wroclaw, krakow, 230).
cena_biletu(gdansk, pozen, 320).
cena_biletu(pozen, gdansk, 320).
cena_biletu(krakow, lublin, 300).
cena_biletu(lublin, krakow, 300).
cena_biletu(warszawa, bialystok, 250).
cena_biletu(bialystok, warszawa, 250).
cena_biletu(bialystok, krakow, 280).
cena_biletu(krakow, bialystok, 280).
cena_biletu(warszawa, katowice, 190).
cena_biletu(katowice, warszawa, 190).
cena_biletu(rybnik, katowice, 80).
cena_biletu(katowice, rybnik, 80).
cena_biletu(wroclaw, szczecin, 250).
cena_biletu(szczecin, wroclaw, 250).
cena_biletu(szczecin, gdansk, 350).
cena_biletu(gdansk, szczecin, 350).
cena_biletu(katowice, pozen, 200).
cena_biletu(pozen, katowice, 200).
cena_biletu(lublin, szczecin, 300).
cena_biletu(szczecin, lublin, 300).
cena_biletu(krakow, rybnik, 210).
cena_biletu(rybnik, krakow, 210).
cena_biletu(warszawa, szczecin, 350).
cena_biletu(szczecin, warszawa, 350).
cena_biletu(wroclaw, katowice, 140).
cena_biletu(katowice, wroclaw, 140).
cena_biletu(bialystok, wroclaw, 320).
cena_biletu(wroclaw, bialystok, 320).
cena_biletu(rybnik, wroclaw, 170).
cena_biletu(wroclaw, rybnik, 170).
cena_biletu(wroclaw, olsztyn, 190).
cena_biletu(olsztyn, wroclaw, 190).
cena_biletu(poznan, rzeszow, 400).
cena_biletu(rzeszow, poznan, 400).
cena_biletu(lublin, olsztyn, 340).
cena_biletu(olsztyn, lublin, 340).
cena_biletu(bialystok, olsztyn, 270).
cena_biletu(olsztyn, bialystok, 270).
cena_biletu(warszawa, rzeszow, 350).
cena_biletu(rzeszow, warszawa, 350).
cena_biletu(szczecin, poznan, 240).
cena_biletu(poznan, szczecin, 240).
cena_biletu(krakow, olsztyn, 320).
cena_biletu(olsztyn, krakow, 320).

% Reguły

% 1. Sprawdzenie połączenia
polaczenie(X, Y) :- polaczenie(X, Y, _).

% 2. Określenie kosztu podróży
koszt_podrozy(X, Y, C) :- polaczenie(X, Y, C).

% 3. Wyznaczenie trasy (rekurencyjnie)
trasa(X, Y, [X, Y], C) :- polaczenie(X, Y, C).
trasa(X, Y, [X | ResztaTrasy], C) :-
    polaczenie(X, Z, C1),
    Z \= Y,
    trasa(Z, Y, ResztaTrasy, C2),
    \+ member(X, ResztaTrasy), % Zapobieganie cyklom
    C is C1 + C2, !.

% 4. Wyznaczenie najkrótszej trasy
najkrotsza_droga(X, Y, Trasa, Koszt) :-
    findall([C, T], trasa(X, Y, T, C), Wyniki),
    sort(Wyniki, [[Koszt, Trasa] | _]).

% 5. Wyszukiwanie wszystkich połączeń między dwoma lotniskami
wszystkie_polaczenia(X, Y, Trasa, Koszt) :-
    trasa(X, Y, Trasa, Koszt).

% 6. Wyznaczenie najtańszej trasy
najtansza_droga(X, Y, Trasa, Koszt) :-
    setof([C, T], trasa(X, Y, T, C), Wyniki),
    Wyniki = [[Koszt, Trasa] | _].

% 7. Zbieranie połączeń do wszystkich lotnisk z danego punktu
polaczenia_z_lotniska(X, Polaczenia) :-
    findall([Y, C], polaczenie(X, Y, C), Polaczenia).

% 8. Sprawdzanie, czy istnieje połączenie między dwoma lotniskami w jednym kroku
bezposrednie_polaczenie(X, Y) :-
    polaczenie(X, Y, _).

# %% [markdown]
# #**Przykładowe zapytania**

# %% [markdown]
# ##**1. Sprawdzenie połączenia**
# ```
# ?- polaczenie(warszawa, krakow).
# ```
# ###**Wynik:**
# ```
# True
# ```
# ##**2. Określenie kosztu podróży**
# ```
# ?- koszt_podrozy(warszawa, krakow, C).
# ```
# ###**Wynik:**
# ```
# 300
# ```
# ##**3. Wyznaczenie trasy (rekurencyjnie)**
# ```
# ?- trasa(warszawa, krakow, Trasa, Koszt).
# ```
# ###**Wynik:**
# ```
# Koszt = 300,
# Trasa = [warszawa, krakow]
# ```
# ##**4. Wyznaczenie najkrótszej trasy**
# ```
# ?- najkrotsza_droga(warszawa, krakow, Trasa, Koszt).
# ```
# ###**Wynik:**
# ```
# Koszt = 300,
# Trasa = [warszawa, krakow]
# ```
# ##**5. Wyszukiwanie wszystkich połączeń między dwoma lotniskami**
# ```
# ?- wszystkie_polaczenia(warszawa, krakow, Trasa, Koszt).
# ```
# ###**Wynik:**
# ```
# Koszt = 300,
# Trasa = [warszawa, krakow]
# Koszt = 700,
# Trasa = [warszawa, gdansk, krakow]
# ```
# ##**6. Wyznaczenie najtańszej trasy**
# ```
# ?- najtansza_droga(krakow, lublin, Trasa, Koszt).
# ```
# ###**Wynik:**
# ```
# Koszt = 350,
# Trasa = [krakow, lublin]
# ```
# ##**7. Zbieranie połączeń do wszystkich lotnisk z danego punktu**
# ```
# ?- polaczenia_z_lotniska(warszawa, Polaczenia).
# ```
# ###**Wynik:**
# ```
# Polaczenia = [[krakow, 300], [gdansk, 500], [wroclaw, 150], [pozen, 180], [bialystok, 280], [katowice, 210], [szczecin, 420], [rzeszow, 400]]
# ```
#
# ##**8. Sprawdzanie, czy istnieje połączenie między dwoma lotniskami w jednym kroku**
# ```
# ?- bezposrednie_polaczenie(warszawa, krakow).
# ```
# ###**Wynik:**
# ```
# True
# ```

# %% [markdown]
# #**Wytłumaczenie:**

# %% [markdown]
# ##**1. Sprawdzenie połączenia**
# ```
# polaczenie(X, Y) :- polaczenie(X, Y, _).
# ```
# ###**Opis:**
#
# - Sprawdza, czy istnieje połączenie między dwoma lotniskami `X` i `Y`.
# - Używa istniejących faktów `polaczenie(X, Y, C)`, gdzie `C` jest dowolny.
# - Wynik to `true`, jeśli takie połączenie istnieje, inaczej `false`.
#
# ##**2. Określenie kosztu podróży**
#
# ```
# koszt_podrozy(X, Y, C) :- polaczenie(X, Y, C).
# ```
# ###**Opis:**
#
# - Znajduje koszt bezpośredniego połączenia między `X` i `Y`.
# - Dopasowuje zmienną `C` do kosztu przechowywanego w fakcie `polaczenie(X, Y, C)`.
# - Jeśli połączenie istnieje, zwraca wartość kosztu, inaczej zapytanie kończy się niepowodzeniem.
#
# ## **3. Wyznaczenie trasy (rekurencyjnie)**
# ```
# trasa(X, Y, [X, Y], C) :- polaczenie(X, Y, C).
# trasa(X, Y, [X | ResztaTrasy], C) :-
#     polaczenie(X, Z, C1),
#     Z \= Y,
#     trasa(Z, Y, ResztaTrasy, C2),
#     \+ member(X, ResztaTrasy),
#     C is C1 + C2.
# ```
# ###**Opis:**
#
# - Pierwsza reguła: Wyznacza trasę dla bezpośredniego połączenia między `X` i `Y`, zwracając `[X, Y]` jako trasę i koszt `C`.
# - Druga reguła: Znajduje trasę wieloetapową przez pośrednie lotniska.
#   - Dopasowuje lotnisko `Z` jako przystanek pośredni między `X` i `Y`.
#   - Wywołuje rekurencyjnie siebie dla trasy `Z → Y`.
#   - Sumuje koszty połączeń etapowych.
#   - Zapobiega zapętleniu za pomocą `\+ member(X, ResztaTrasy)`.
#
# ## **4. Wyznaczenie najkrótszej trasy**
#
# ```
# najkrotsza_droga(X, Y, Trasa, Koszt) :-
#     findall([C, T], trasa(X, Y, T, C), Wyniki),
#     sort(Wyniki, [[Koszt, Trasa] | _]).
# ```
# ###**Opis:**
#
# - Zbiera wszystkie możliwe trasy z `X` do `Y` za pomocą `findall/3`.
# - Każda trasa jest przechowywana w formacie `[Koszt, Trasa]`.
# - Sortuje trasy według kosztu i zwraca pierwszą jako najkrótszą.
# - Jeśli nie ma trasy, zapytanie kończy się niepowodzeniem.
#
# ##**5. Wyszukiwanie wszystkich połączeń**
# ```
# wszystkie_polaczenia(X, Y, Trasa, Koszt) :-
#     trasa(X, Y, Trasa, Koszt).
# ```
# ###**Opis:**
#
# - Znajduje wszystkie możliwe trasy z `X` do `Y`, w tym wieloetapowe.
# - Wykorzystuje regułę `trasa/4` do generowania tras i przypisywania ich kosztów.
# - Nie sortuje ani nie filtruje wyników.
#
# ##**6. Wyznaczenie najtańszej trasy**
#
# ```
# najtansza_droga(X, Y, Trasa, Koszt) :-
#     setof([C, T], trasa(X, Y, T, C), Wyniki),
#     Wyniki = [[Koszt, Trasa] | _].
# ```
# ###**Opis:**
#
# - Zbiera wszystkie trasy z `X` do `Y` w formacie `[Koszt, Trasa]`, korzystając z setof/3.
# - Wyniki są automatycznie uporządkowane rosnąco według kosztu.
# - Zwraca trasę o najmniejszym koszcie jako pierwszy element listy.
# - Jeśli brak trasy, zapytanie kończy się niepowodzeniem.
#
# ##**7. Zbieranie połączeń z lotniska**
#
# ```
# polaczenia_z_lotniska(X, Polaczenia) :-
#     findall([Y, C], polaczenie(X, Y, C), Polaczenia).
# ```
# ###**Opis:**
#
# - Zbiera wszystkie połączenia wychodzące z lotniska X w formie listy [Y, C], gdzie Y to cel, a C to koszt.
# - Wykorzystuje findall/3 do wygenerowania listy wszystkich dopasowanych wyników.
# - Wynik to lista par [cel, koszt].
#
# ##**8. Sprawdzanie bezpośredniego połączenia**
#
# ```
# bezposrednie_polaczenie(X, Y) :-
#     polaczenie(X, Y, _).
# ```
# ###**Opis:**
#
# - Sprawdza, czy istnieje bezpośrednie połączenie między lotniskami `X` i `Y`.
# - Używa faktów `polaczenie(X, Y, C)`, ignorując wartość C.
# - Wynik to `true` dla istniejącego połączenia lub false w przeciwnym przypadku.

# %% [markdown]
# # Zadanie 3: System zarządzania magazynem

# %%
% Deklaracja predykatu dynamicznego
:- dynamic produkt/3.
produkt(telewizor_Sony_4k, 10, sektor_a).
produkt(pralka_Bosch_bębnowa, 5, sektor_b).
produkt(lodówka_Samsung_side_by_side, 3, sektor_c).
produkt(suszarka_Bosch_bębnowa, 7, sektor_d).
produkt(zmywarka_Miele_podblatowa, 4, sektor_e).
produkt(mikrofalówka_Samsung_smart, 12, sektor_f).
produkt(komputer_Dell_stacjonarny, 8, sektor_g).
produkt(telewizor_LG_led, 6, sektor_h).
produkt(klimatyzator_Whirlpool_ścienny, 2, sektor_i).
produkt(odkurzacz_Dyson_bezprzewodowy, 11, sektor_j).
produkt(kuchnia_Faber_indukcyjna, 1, sektor_k).
produkt(pralka_Siemens_ładowana_od_frontu, 3, sektor_l).
produkt(lodówka_Beko_dwudrzwiowa, 5, sektor_m).
produkt(suszarka_AEG_do_ubran, 9, sektor_n).
produkt(mikrofalówka_Panasonic_z_grillem, 6, sektor_o).
produkt(komputer_HP_laptop, 10, sektor_p).
produkt(ekspres_Nivona_do_kawy_automatyczny, 4, sektor_q).
produkt(kuchenka_Gorenje_gazowa, 15, sektor_r).
produkt(telewizor_Samsung_qled, 7, sektor_s).
produkt(klimatyzator_Mitsubishi_przenośny, 2, sektor_t).
produkt(odkurzacz_Roomba_robotyczny, 12, sektor_u).
produkt(lodówka_Siemens_z_wydzielonym_zamrażalnikiem, 6, sektor_v).
produkt(pralka_Indesit_energooszczędna, 4, sektor_w).
produkt(wentylator_Vornado_przemysłowy, 14, sektor_x).
produkt(lodówka_Liebherr_szeroka, 8, sektor_y).
produkt(kuchenka_Amica_elektryczna, 2, sektor_z).
produkt(telewizor_TCL_8k, 11, sektor_aa).
produkt(odkurzacz_Bosch_bezprzewodowy_pro, 13, sektor_ab).
produkt(mikrofalówka_Samsung_inwerterowa, 3, sektor_ac).
produkt(suszarka_Philips_do_włosów, 6, sektor_ad).
produkt(ekspres_Do_espresso_Saeco, 9, sektor_ae).
produkt(pralka_Washer_kompaktowa, 5, sektor_af).
produkt(telewizor_Sony_smart, 10, sektor_ag).
produkt(pralka_Zanussi_ze_suszarką, 7, sektor_ah).
produkt(mikrofalówka_LG_pozioma, 8, sektor_ai).
produkt(zmywarka_Bosch_do_zabudowy, 5, sektor_aj).
produkt(wentylator_Lasko_wieczorny, 4, sektor_ak).
produkt(kuchnia_Beko_na_wymiar, 9, sektor_al).
produkt(komputer_Lenovo_zakupowy, 7, sektor_am).
produkt(telewizor_Samsung_50_smart, 2, sektor_an).
produkt(suszarka_Wagner_wybuchowa, 10, sektor_ao).
produkt(odkurzacz_Vax_energooszczędny, 13, sektor_ap).
produkt(pralka_Beko_ekologiczna, 6, sektor_aq).
produkt(lodówka_Electrolux_mini, 14, sektor_ar).
produkt(mikrofalówka_Hitachi_jednopokojowa, 3, sektor_as).
produkt(telewizor_Philips_plazmowy, 6, sektor_at).
produkt(zmywarka_Kenmore_wielkospalinowa, 12, sektor_au).
produkt(wentylator_Dyson_wielofunkcyjny, 5, sektor_av).
produkt(suszarka_Air_Pro_na_balkon, 8, sektor_aw).
produkt(lodówka_Samsung_wewnętrzna, 7, sektor_ax).
produkt(komputer_Apple_mobilny, 13, sektor_ay).
produkt(pralka_Panasonic_pionowa, 4, sektor_az).
produkt(telewizor_Toshiba_tradycyjny, 10, sektor_ba).
produkt(lodówka_Miele_dziewięciogwiazdkowa, 9, sektor_bb).
produkt(zmywarka_Miele_automatyczna, 5, sektor_bc).
produkt(odkurzacz_Bissell_mocny, 14, sektor_bd).
produkt(mikrofalówka_Beko_turbo, 3, sektor_be).
produkt(suszarka_Winix_przemysłowa, 8, sektor_bf).
produkt(lodówka_Bosch_inwestycyjna, 11, sektor_bg).
produkt(ekspres_Jura_do_kawy_espresso, 7, sektor_bh).
produkt(telewizor_Sony_eco, 2, sektor_bi).
produkt(komputer_Asus_złożony, 13, sektor_bj).
produkt(mikrofalówka_Miele_digital, 9, sektor_bk).
produkt(pralka_LG_mistrzowska, 4, sektor_bl).
produkt(suszarka_Hoover_bordowa, 6, sektor_bm).
produkt(telewizor_LG_hd, 15, sektor_bn).
produkt(lodówka_Gorenje_przemysłowa, 12, sektor_bo).
produkt(komputer_Sony_tablet, 5, sektor_bp).
produkt(ekspres_Krups_kawy_turbo, 10, sektor_bq).
produkt(suszarka_AEG_model_eco, 9, sektor_br).
produkt(pralka_Bosch_nowoczesna, 7, sektor_bs).
produkt(telewizor_LG_technologiczny, 13, sektor_bt).
produkt(zmywarka_Electrolux_zintegrowana, 6, sektor_bu).
produkt(komputer_Macbook_laptop_gamingowy, 10, sektor_bv).
produkt(lodówka_Beko_mini_barska, 8, sektor_bw).
produkt(telewizor_Samsung_monitor, 2, sektor_bx).
produkt(suszarka_Miele_super, 11, sektor_by).
produkt(odkurzacz_Technos_mocniejszy, 4, sektor_bz).
produkt(ekspres_Caffitaly_novum, 9, sektor_ca).
produkt(mikrofalówka_Electrolux_ekspresowa, 13, sektor_cb).
produkt(komputer_Corsair_dedykowany, 5, sektor_cc).
produkt(zmywarka_Bosch_przemysłowa, 10, sektor_cd).
produkt(telewizor_Philips_oled, 6, sektor_ce).
produkt(lodówka_Whirlpool_chłodnia, 12, sektor_cf).
produkt(suszarka_Whirlpool_szybka, 4, sektor_cg).
produkt(pralka_AEG_pionowa, 8, sektor_ch).
produkt(mikrofalówka_Frigidaire_wysokiej_jakości, 10, sektor_ci).
produkt(odkurzacz_Vacuum_skrócony, 13, sektor_cj).
produkt(telewizor_Samsung_mini, 7, sektor_ck).
produkt(kuchnia_Miele_konkretna, 5, sektor_cl).

% Reguły

% Sprawdzenie, czy produkt jest dostępny
dostepny_produkt(X) :-
    produkt(X, Ilosc, _),
    Ilosc > 0.

% Przeniesienie produktu do innego sektora
przenies_produkt(X, NowySektor) :-
    produkt(X, Ilosc, _),
    Ilosc > 0,
    retract(produkt(X, Ilosc, _)),
    assertz(produkt(X, Ilosc, NowySektor)).

% Uzupełnienie stanu produktu
uzupelnij_stan(X, N) :-
    produkt(X, Ilosc, Sektor),
    Ilosc > 0,
    retract(produkt(X, Ilosc, Sektor)),
    NowaIlosc is Ilosc + N,
    assertz(produkt(X, NowaIlosc, Sektor)).

% Sprawdzenie dostępności produktu w określonym sektorze
dostepny_w_sektorze(X, Sektor) :-
    produkt(X, Ilosc, Sektor),
    Ilosc > 0.

% Znajdowanie produktów w określonym sektorze
produkty_w_sektorze(Sektor, Produkty) :-
    findall(X, produkt(X, _, Sektor), Produkty).

% Usuwanie produktu z bazy danych
usun_produkt(X) :-
    produkt(X, Ilosc, _),
    Ilosc = 0,
    retract(produkt(X, Ilosc, _)).

% Lista produktów z ich ilościami
lista_produktow :-
    listing(produkt).

% Tworzenie raportu z dostępnych produktów
raport_dostepnych :-
    findall((X, Ilosc, Sektor), (produkt(X, Ilosc, Sektor), Ilosc > 0), Raport),
    writeln('Raport dostępnych produktów:'),
    writeln(Raport).

% Sortowanie produktów według ilości
sortuj_produkty_po_ilosci(Sorted) :-
    findall((X, Ilosc, Sektor), produkt(X, Ilosc, Sektor), Produkty),
    sort(2, @>=, Produkty, Sorted).  % Sortowanie po ilości (2. element w krotce)

# %% [markdown]
# #**Przykładowe zapytania**

# %% [markdown]
# ##**1. Sprawdzenie, czy produkt jest dostępny**
# ```
# ?- dostepny_produkt(telewizor_Sony_4k).
# ```
# ###**Wynik:**
# ```
# True
# ```
# ##**2. Przeniesienie produktu do innego sektora**
# ```
# ?- przenies_produkt(telewizor_Sony_4k, sektor_z).
# ```
# ###**Wynik:**
# ```
# True
# ```
# ##**3. Uzupełnienie stanu produktu**
# ```
# ?- uzupelnij_stan(telewizor_Sony_4k, 5).
# ```
# ###**Wynik:**
# ```
# True
# ```
# ##**4. Sprawdzenie dostępności produktu w określonym sektorze**
# ```
# ?- dostepny_w_sektorze(telewizor_Sony_4k, sektor_a).
# ```
# ###**Wynik:**
# ```
# True
# ```
# ##**5. Znajdowanie produktów w określonym sektorze**
# ```
# ?- produkty_w_sektorze(sektor_a, Produkty).
# ```
# ###**Wynik:**
# ```
# Produkty = [telewizor_Sony_4k]
# ```
#
# ##**6. Usuwanie produktu z bazy danych**
# ```
# ?- usun_produkt(telewizor_Sony_eco).
# ```
# ###**Wynik:**
# ```
# False
# ```
# *nie wiem czemu :(*
# ##**7. Lista produktów z ich ilościami**
# ```
# ?- lista_produktow. +
# ```
# ###**Wynik:**
# ```
# True [Wypisał wszystkie produkty]
# ```
#
# ##**8. Tworzenie raportu z dostępnych produktów**
# ```
# ?- raport_dostepnych.
# ```
# ###**Wynik:**
# ```
# True [Wypisał raport dostępnych produktów]
# ```
# ##**9. Sortowanie produktów według ilości**
# ```
# ?- sortuj_produkty_po_ilosci(Sorted).
# ```
# ###**Wynik:**
# ```
# True [posegregował dostępne produkty]
# ```

# %% [markdown]
# #**Wytłumaczenie:**

# %% [markdown]
# ##  **1. Sprawdzenie, czy produkt jest dostępny:**
# ```
# dostepny_produkt(X) :-
#     produkt(X, Ilosc, _),
#     Ilosc > 0.
# ```
# ###**Opis:**
# - Reguła sprawdza, czy istnieje produkt `X` (`telewizor_Sony_4k`) w bazie danych (produkt(X, Ilosc, _)).
# - Następnie sprawdza, czy jego ilość (`Ilosc`) jest większa niż 0 (`Ilosc > 0`).
# - Jeśli produkt ma ilość większą niż 0, zapytanie zwróci prawdę, oznaczając, że produkt jest dostępny.
#
# ## **2. Przeniesienie produktu do innego sektora:**
# ```
# przenies_produkt(X, NowySektor) :-
#     produkt(X, Ilosc, _),
#     Ilosc > 0,
#     retract(produkt(X, Ilosc, _)),
#     assertz(produkt(X, Ilosc, NowySektor)).
# ```
# ###**Opis:**
#
# - Reguła sprawdza, czy produkt `X` (`telewizor_Sony_4k`) istnieje w bazie danych i czy jego ilość jest większa niż 0.
# - `retract(produkt(X, Ilosc, _))` usuwa istniejący wpis o produkcie z poprzedniego sektora.
# - `assertz(produkt(X, Ilosc, NowySektor))` dodaje produkt z tą samą ilością (`Ilosc`) do nowego sektora (`NowySektor`).
# - Jeśli produkt jest dostępny, zostanie przeniesiony do sektora `sektor_z`.
#
# ## **3. Uzupełnienie stanu produktu:**
# ```
# uzupelnij_stan(X, N) :-
#     produkt(X, Ilosc, Sektor),
#     Ilosc > 0,
#     retract(produkt(X, Ilosc, Sektor)),
#     NowaIlosc is Ilosc + N,
#     assertz(produkt(X, NowaIlosc, Sektor)).
# ```
#
# ### **Opis:**
# - Reguła sprawdza, czy produkt `X` (`telewizor_Sony_4k`) istnieje w bazie danych, a jego ilość jest większa niż 0.
# - Następnie produkt zostaje usunięty z bazy `retract(produkt(X, Ilosc, Sektor))`.
# - Ilość produktu zostaje zwiększona o `N`, tworząc nową ilość `NowaIlosc`.
# - Nowa ilość zostaje zapisana w bazie danych, przy czym produkt pozostaje w tym samym sektorze `assertz(produkt(X, NowaIlosc, Sektor))`.
# - Po wykonaniu zapytania ilość produktu `telewizor_Sony_4k` zostaje zwiększona o 5.
#
# ## **4. Sprawdzenie dostępności produktu w określonym sektorze:**
# ```
# dostepny_w_sektorze(X, Sektor) :-
#     produkt(X, Ilosc, Sektor),
#     Ilosc > 0.
# ```
# ###**Opis:**
# - Reguła sprawdza, czy produkt `X` istnieje w sektorze `Sektor`.
# - Jeśli produkt znajduje się w tym sektorze i jego ilość jest większa niż **0** (`Ilosc > 0`), zapytanie zwróci prawdę.
# - Jeśli produkt jest dostępny w danym sektorze, wynik to `true`.
#
# ##**5. Znajdowanie produktów w określonym sektorze:**
# ```
# produkty_w_sektorze(Sektor, Produkty) :-
#     findall(X, produkt(X, _, Sektor), Produkty).
# ```
#
# ### **Opis:**
# - Reguła `findall(X, produkt(X, _, Sektor), Produkty)` zbiera wszystkie produkty X, które znajdują się w danym sektorze (`Sektor`).
# - Dla sektora `sektor_a` zostanie zwrócony listę produktów, które się tam znajdują.
# - W wyniku tego zapytania, `Produkty` zawiera listę produktów, w tym przypadku tylko `telewizor_Sony_4k`.
#
# ##**6. Usuwanie produktu z bazy danych:**
# ```
# usun_produkt(X) :-
#     produkt(X, Ilosc, _),
#     Ilosc = 0,
#     retract(produkt(X, Ilosc, _)).
# ```
#
# ###**Opis:**
# - Reguła sprawdza, czy produkt `X` `telewizor_Sony_eco` ma ilość równą 0 (`Ilosc = 0`).
# - Jeśli ilość wynosi 0, produkt zostaje usunięty z bazy danych za pomocą `(produkt(X, Ilosc, _))`.
# - Jeśli ilość produktu jest większa niż 0, produkt nie zostanie usunięty. W przypadku zapytania o produkt, który ma ilość większą niż 0, zapytanie nie wykona się.
#
# ## **7. Lista produktów z ich ilościami:**
# ```
# lista_produktow :-
#     listing(produkt).
# ```
# ###**Opis:**
# - Reguła `listing(produkt)` wypisuje wszystkie produkty w bazie danych, wyświetlając je w postaci ich definicji.
# - Zapytanie wyświetli wszystkie produkty zapisane w bazie, wraz z ich ilościami i sektorami.
#
# ##**8. Tworzenie raportu z dostępnych produktów:**
# ```
# raport_dostepnych :-
#     findall((X, Ilosc, Sektor), (produkt(X, Ilosc, Sektor), Ilosc > 0), Raport),
#     writeln('Raport dostępnych produktów:'),
#     writeln(Raport).
# ```
#
# ###**Opis:**
# - Reguła `findall((X, Ilosc, Sektor), (produkt(X, Ilosc, Sektor), Ilosc > 0)`, Raport) zbiera wszystkie produkty, które mają ilość większą niż 0.
# - Produkty te zostają zapisane w zmiennej `Raport` i wypisane za pomocą `writeln`.
# - Zapytanie zwróci raport produktów dostępnych w bazie danych.
#
# ##**9. Sortowanie produktów według ilości:**
#
# ```
# sortuj_produkty_po_ilosci(Sorted) :-
#     findall((X, Ilosc, Sektor), produkt(X, Ilosc, Sektor), Produkty),
#     sort(2, @>=, Produkty, Sorted).
# ```
# ### **Opis:**
# - Reguła `findall((X, Ilosc, Sektor), produkt(X, Ilosc, Sektor), Produkty)` zbiera wszystkie produkty w bazie.
# - `sort(2, @>=, Produkty, Sorted)` sortuje je według ilości w porządku malejącym `(@>=)`.
# - Zapytanie zwróci posortowaną listę produktów według ilości, od największej do najmniejszej.

# %% [markdown]
# # Zadanie 4: System planowania trasy kuriera

# %%
miasto(warszawa).
miasto(krakow).
miasto(poznan).
miasto(wroclaw).
miasto(gdansk).
miasto(szczecin).
miasto(lublin).
miasto(bialystok).
miasto(katowice).
miasto(rzeszow).
miasto(opole).
miasto(torun).
miasto(legnica).
miasto(olsztyn).
miasto(koszalin).
miasto(gorzow).
miasto(zielona_gora).
miasto(suwalki).
miasto(mazury).
miasto(radom).

droga(warszawa, krakow, 5).
droga(krakow, warszawa, 5).
droga(krakow, poznan, 4).
droga(poznan, krakow, 4).
droga(warszawa, poznan, 3).
droga(poznan, warszawa, 3).
droga(wroclaw, warszawa, 5).
droga(warszawa, wroclaw, 5).
droga(gdansk, warszawa, 5).
droga(warszawa, gdansk, 5).
droga(szczecin, warszawa, 5).
droga(warszawa, szczecin, 5).
droga(lublin, warszawa, 2).
droga(warszawa, lublin, 2).
droga(bialystok, warszawa, 4).
droga(warszawa, bialystok, 4).
droga(krakow, wroclaw, 3).
droga(wroclaw, krakow, 3).
droga(krakow, gdansk, 5).
droga(gdansk, krakow, 5).
droga(krakow, szczecin, 6).
droga(szczecin, krakow, 6).
droga(poznan, wroclaw, 2).
droga(wroclaw, poznan, 2).
droga(poznan, gdansk, 5).
droga(gdansk, poznan, 5).
droga(poznan, szczecin, 4).
droga(szczecin, poznan, 4).
droga(krakow, opole, 3).
droga(opole, krakow, 3).
droga(krakow, torun, 3).
droga(torun, krakow, 3).
droga(warszawa, opole, 3).
droga(opole, warszawa, 3).
droga(warszawa, torun, 3).
droga(torun, warszawa, 3).
droga(warszawa, legnica, 4).
droga(legnica, warszawa, 4).
droga(warszawa, olsztyn, 4).
droga(olsztyn, warszawa, 4).
droga(krakow, legnica, 4).
droga(legnica, krakow, 4).
droga(wroclaw, opole, 1).
droga(opole, wroclaw, 1).
droga(gdansk, wroclaw, 6).
droga(wroclaw, gdansk, 6).
droga(gdansk, szczecin, 4).
droga(szczecin, gdansk, 4).
droga(szczecin, wroclaw, 5).
droga(wroclaw, szczecin, 5).
droga(lublin, bialystok, 2).
droga(bialystok, lublin, 2).
droga(lublin, katowice, 4).
droga(katowice, lublin, 4).
droga(rzeszow, bialystok, 4).
droga(bialystok, rzeszow, 4).
droga(opole, katowice, 3).
droga(katowice, opole, 3).
droga(torun, rzeszow, 4).
droga(rzeszow, torun, 4).
droga(legnica, katowice, 4).
droga(katowice, legnica, 4).
droga(olsztyn, warszawa, 4).
droga(warszawa, olsztyn, 4).
droga(gorzow, szczecin, 1).
droga(szczecin, gorzow, 1).
droga(gorzow, bialystok, 7).
droga(bialystok, gorzow, 7).
droga(zielona_gora, bialystok, 5).
droga(bialystok, zielona_gora, 5).
droga(koszalin, bialystok, 6).
droga(bialystok, koszalin, 6).

% Dodatkowe połączenia
droga(radom, warszawa, 1).
droga(warszawa, radom, 1).
droga(suwalki, bialystok, 2).
droga(bialystok, suwalki, 2).
droga(mazury, bialystok, 3).
droga(bialystok, mazury, 3).
droga(mazury, warszawa, 4).
droga(warszawa, mazury, 4).
droga(koszalin, szczecin, 2).
droga(szczecin, koszalin, 2).
droga(koszalin, wroclaw, 6).
droga(wroclaw, koszalin, 6).
droga(katowice, gorzow, 5).
droga(gorzow, katowice, 5).
droga(zielona_gora, katowice, 5).
droga(katowice, zielona_gora, 5).
droga(zielona_gora, rzeszow, 6).
droga(rzeszow, zielona_gora, 6).
droga(torun, koszalin, 5).
droga(koszalin, torun, 5).
droga(olsztyn, suwalki, 3).
droga(suwalki, olsztyn, 3).

% Reguła sprawdzająca, czy istnieje bezpośrednie połączenie między miastami X i Y
droga(X, Y) :- droga(X, Y, _).

% Reguła obliczająca czas przejazdu między dwoma miastami, uwzględniająca połączenia pośrednie
czas_przejazdu(X, Y, T) :-
    droga(X, Y, T). % Bezpośrednie połączenie
czas_przejazdu(X, Y, T) :-
    droga(X, Z, T1), % Połączenie do miasta pośredniego Z
    \+ member(Z, [X]), % Zapobiegamy powtarzaniu się miasta Z
    czas_przejazdu(Z, Y, T2), % Czas przejazdu od Z do Y
    (   T2 = infinity -> T = infinity % Jeśli brak dalszej trasy
    ;   T is T1 + T2 % Sumowanie czasu, jeśli istnieje dalsza trasa
    ).

% Reguła wyznaczająca najkrótszą trasę między dwoma miastami
najkrotsza_trasa(X, Y, NajkrotszaTrasa, NajkrotszyCzas) :-
    (   findall((Trasa, Czas), znajdz_trase(X, Y, Trasa, Czas), Trasy)
    ->  sort(2, @=<, Trasy, [(NajkrotszaTrasa, NajkrotszyCzas) | _])
    ;   NajkrotszaTrasa = [], NajkrotszyCzas = infinity % Brak dostępnych tras
    ).

% Pomocnicza reguła do znajdowania wszystkich możliwych tras
znajdz_trase(X, Y, [X, Y], Czas) :-
    droga(X, Y, Czas).
znajdz_trase(X, Y, [X | Trasa], Czas) :-
    droga(X, Z, Czas1),
    Z \= Y,
    \+ member(Z, [X | Trasa]), % Unikamy cykli
    znajdz_trase(Z, Y, Trasa, Czas2),
    (   Czas2 = infinity -> Czas = infinity
    ;   Czas is Czas1 + Czas2
    ).

% Reguła znajdowania wszystkich miast, które można osiągnąć z miasta X
miasta_dostepne(X, Miasta) :-
    findall(Y, (droga(X, Y, _); droga(Y, X, _)), MiastaUnikalne),
    list_to_set(MiastaUnikalne, Miasta).  % Usuń duplikaty, aby mieć unikalne miasta

% Dodawanie nowego połączenia do bazy danych
dodaj_droga(X, Y, Czas) :-
    assertz(droga(X, Y, Czas)),
    assertz(droga(Y, X, Czas)).

% Usuwanie połączenia z bazy danych
usun_droga(X, Y) :-
    retract(droga(X, Y, _)),
    retract(droga(Y, X, _)).

% Reguła sprawdzająca, czy droga działa w obie strony
droga_obie_strony(X, Y) :-
    droga(X, Y, _),
    droga(Y, X, _).

% Liczy liczbę połączeń dla danego miasta
liczba_polaczen(Miasto, Liczba) :-
    findall(1, droga(Miasto, _, _), Polaczenia1), % Połączenia wychodzące
    findall(1, droga(_, Miasto, _), Polaczenia2), % Połączenia przychodzące
    append(Polaczenia1, Polaczenia2, WszystkiePolaczenia),
    length(WszystkiePolaczenia, Liczba). % Liczba wszystkich połączeń

% Znajduje miasto z największą liczbą połączeń
miasto_z_najwieksza_liczba_polaczen(Miasto) :-
    findall((Liczba, Miasto), (miasto(Miasto), liczba_polaczen(Miasto, Liczba)), Polaczenia),
    max_member((_, Miasto), Polaczenia). % Znajduje miasto z największą liczbą połączeń

# %% [markdown]
# #**Przykładowe zapytania**

# %% [markdown]
# ##**1. Sprawdzenie, czy istnieje bezpośrednie połączenie między X a Y**
# ```
# droga(warszawa, krakow).
# ```
# ###**Wynik:**
# ```
# True
# ```
# ##**2. Reguła obliczająca czas przejazdu między dwoma miastami, uwzględniająca połączenia pośrednie**
# ```
# ?- czas_przejazdu(warszawa, krakow, Czas).
# ```
# ###**Wynik:**
# ```
# Czas = 5
# Czas = 15
# Czas = 25
# Czas = 35
# ...
# ```
# ##**3. Reguła wyznaczająca najkrótszą trasę między dwoma miastami**
# ```
# ?- najkrotsza_trasa(warszawa, krakow, Trasa, Czas).
#
# ```
# ###**Wynik:**
# ```
# Czas = 5,
# Trasa = [warszawa, krakow]
# ```
# ##**4. Reguła znajdowania wszystkich miast, które można osiągnąć z miasta X**
# ```
# ?- miasta_dostepne(warszawa, Miasta).
# ```
# ###**Wynik:**
# ```
# Miasta = [krakow, poznan, wroclaw, gdansk, szczecin, lublin, bialystok, opole, torun, legnica, olsztyn, radom, mazury]
# ```
# ##**5. Dodawanie nowego połączenia do bazy danych**
# ```
# ?- dodaj_droga(zielona_gora, warszawa, 8)
# ```
# ###**Wynik:**
# ```
# True
# ```
# ##**6. Usuwanie połączenia z bazy danych**
# ```
# ?- usun_droga(warszawa, krakow).
# ```
# ###**Wynik:**
# ```
# True
# ```
# ##**7. Reguła sprawdzająca, czy droga działa w obie strony**
# ```
# ?- droga_obie_strony(warszawa, krakow).
# ```
# ###**Wynik:**
# ```
# True
# ```
# ##**8. Reguła znajdująca miasto z największą liczbą połączeń**
# ```
# ?- miasto_z_najwieksza_liczba_polaczen(Miasto).
# ```
# ###**Wynik:**
# ```
# Miasto = warszawa
# ```

# %% [markdown]
# #**Wytłumaczenie:**

# %% [markdown]
# ##**1. Sprawdzanie, czy istnieje bezpośrednie połączenie**
#
# ```
# droga(X, Y) :- droga(X, Y, _).
# ```
# ###**Opis:**
# - Reguła sprawdza, czy istnieje bezpośrednia droga między `X` i `Y`, niezależnie od czasu przejazdu (`_` oznacza zmienną, której wartość jest ignorowana).
#  - Prolog przeszukuje bazę danych w poszukiwaniu faktów w formacie `droga(X, Y, _)`.
#   - Jeśli taki fakt istnieje, wynik to true.
#
# ## **2. Obliczanie czasu przejazdu**
#
# ```
# czas_przejazdu(X, Y, T) :-
#     droga(X, Y, T).
# czas_przejazdu(X, Y, T) :-
#     droga(X, Z, T1),
#     \+ member(Z, [X]),
#     czas_przejazdu(Z, Y, T2),
#     (   T2 = infinity -> T = infinity
#     ;   T is T1 + T2
#     ).
# ```
# ###**Opis:**
#
# - Jeśli istnieje bezpośrednia droga między `X` i `Y`, czas przejazdu `T` jest pobierany bezpośrednio z faktu `droga(X, Y, T)`.
# - Druga część reguły:
#   - Sprawdza połączenia pośrednie `X -> Z -> Y`.
#   - `T1` to czas przejazdu między `X` i `Z`.
#   - Rekurencyjnie wywoływana jest reguła `czas_przejazdu(Z, Y, T2)` dla dalszej trasy.
#   - Jeśli nie można znaleźć trasy do `Y`, zwraca infinity.
#
#
# ##**3. Wyznaczanie najkrótszej trasy**
#
# ```
# najkrotsza_trasa(X, Y, NajkrotszaTrasa, NajkrotszyCzas) :-
#     (   findall((Trasa, Czas), znajdz_trase(X, Y, Trasa, Czas), Trasy)
#     ->  sort(2, @=<, Trasy, [(NajkrotszaTrasa, NajkrotszyCzas) | _])
#     ;   NajkrotszaTrasa = [], NajkrotszyCzas = infinity
#     ).
# ```
# ###**Opis:**
# - Pomocnicza reguła `znajdz_trase` znajduje wszystkie możliwe trasy między `X` i `Y` wraz z ich czasami.
# Funkcja `findall` tworzy listę wszystkich tras i czasów w formacie `[(Trasa1,Czas1), (Trasa2, Czas2), ...]`.
# - Funkcja `sort` sortuje listę tras według czasu przejazdu.
# - Najkrótsza trasa: Pierwszy element posortowanej listy to najkrótsza trasa.
#
# ##**4. Znajdowanie wszystkich dostępnych miast**
# ```
# miasta_dostepne(X, Miasta) :-
#     findall(Y, (droga(X, Y, _); droga(Y, X, _)), MiastaUnikalne),
#     list_to_set(MiastaUnikalne, Miasta).
# ```
# ###**Opis:**
#
# - Funkcja `findall` zbiera wszystkie miasta `Y`, do których istnieją drogi z miasta `X` (w obu kierunkach).
# - Funkcja `list_to_set` usuwa duplikaty, tworząc listę unikalnych miast.
#
#
# ##**5. Dodawanie nowego połączenia**
#
# ```
# dodaj_droga(X, Y, Czas) :-
#     assertz(droga(X, Y, Czas)),
#     assertz(droga(Y, X, Czas)).
# ```
# ###**Opis:**
#
# - Funkcja `assertz` dodaje nowe fakty `droga(X, Y, Czas)` i` droga(Y, X, Czas)` do bazy danych.
# - Nowe połączenie działa w obu kierunkach.
#
# ##**6.Usuwanie połączenia**
#
# ```
# usun_droga(X, Y) :-
#     retract(droga(X, Y, _)),
#     retract(droga(Y, X, _)).
# ```
# ###**Opis:**
# - Funkcja `retract: Usuwa istniejące fakty droga(X, Y, _) i droga(Y, X, _) z bazy danych.
#
# ## **7. Sprawdzanie dwukierunkowości drogi**
# ```
# droga_obie_strony(X, Y) :-
#     droga(X, Y, _),
#     droga(Y, X, _).
# ```
#
# ###**Opis:**
#
# - Sprawdza, czy istnieją drogi `X -> Y` i `Y -> X` w bazie danych.
#
# ## **8. Znalezienie miasta z największą liczbą połączeń**
# ```
# miasto_z_najwieksza_liczba_polaczen(Miasto) :-
#     findall((Liczba, Miasto), (miasto(Miasto), liczba_polaczen(Miasto, Liczba)), Polaczenia),
#     max_member((_, Miasto), Polaczenia).
# ```
# ###**Opis:**
# - Funkcja `findall` tworzy listę miast i ich liczby połączeń.
# - Funkcja `max_member` znajduje miasto z największą liczbą połączeń.

# %% [markdown]
# # Zadanie 5: System rekomendacji książek

# %%
% Fakty dotyczące książek
ksiazka('W pustyni i w puszczy', sienkiewicz, przygodowa).
ksiazka('Hobbit', tolkien, fantasy).
ksiazka('Pan Tadeusz', mickiewicz, poezja).
ksiazka('Duma i uprzedzenie', austen, romans).
ksiazka('Władca pierścieni', tolkien, fantasy).
ksiazka('Zbrodnia i kara', dostojewski, kryminał).
ksiazka('Mistrz i Małgorzata', bułhakow, fantasy).
ksiazka('Pani Bovary', flaubert, romans).
ksiazka('Harry Potter i Kamień Filozoficzny', rowling, fantasy).
ksiazka('1984', orwell, dystopia).
ksiazka('Zabić drozda', lee, dramat).
ksiazka('Cień wiatru', zafon, thriller).
ksiazka('Przeminęło z wiatrem', mitchell, romans).
ksiazka('Wielki Gatsby', fitzgerald, literatura_klasyczna).
ksiazka('Lalka', prus, powiesc_spoleczna).
ksiazka('Moby Dick', melville, przygodowa).
ksiazka('Frankenstein', shelley, horror).
ksiazka('Sherlock Holmes', doyle, kryminał).
ksiazka('Wojna i pokój', tolstoj, historyczna).
ksiazka('Odyseja', homer, epika).
ksiazka('Złodziejka książek', zusak, dramat).

% Fakty dotyczące ocen
ocena(uzytkownik1, 'W pustyni i w puszczy', 5).
ocena(uzytkownik1, 'Hobbit', 4).
ocena(uzytkownik1, 'Pan Tadeusz', 3).
ocena(uzytkownik1, 'Duma i uprzedzenie', 5).
ocena(uzytkownik1, 'Władca pierścieni', 5).
ocena(uzytkownik1, 'Zbrodnia i kara', 4).
ocena(uzytkownik1, 'Mistrz i Małgorzata', 5).
ocena(uzytkownik1, 'Pani Bovary', 3).
ocena(uzytkownik1, 'Harry Potter i Kamień Filozoficzny', 5).
ocena(uzytkownik1, '1984', 4).
ocena(uzytkownik1, 'Zabić drozda', 5).
ocena(uzytkownik1, 'Cień wiatru', 4).
ocena(uzytkownik1, 'Przeminęło z wiatrem', 3).
ocena(uzytkownik1, 'Wielki Gatsby', 5).
ocena(uzytkownik1, 'Lalka', 4).
ocena(uzytkownik1, 'Moby Dick', 4).
ocena(uzytkownik1, 'Frankenstein', 3).
ocena(uzytkownik1, 'Sherlock Holmes', 5).
ocena(uzytkownik1, 'Wojna i pokój', 4).
ocena(uzytkownik1, 'Odyseja', 5).
ocena(uzytkownik1, 'Złodziejka książek', 5).

ocena(uzytkownik2, 'W pustyni i w puszczy', 4).
ocena(uzytkownik2, 'Hobbit', 5).
ocena(uzytkownik2, 'Pan Tadeusz', 2).
ocena(uzytkownik2, 'Duma i uprzedzenie', 3).
ocena(uzytkownik2, 'Władca pierścieni', 5).
ocena(uzytkownik2, 'Zbrodnia i kara', 5).
ocena(uzytkownik2, 'Mistrz i Małgorzata', 3).
ocena(uzytkownik2, 'Pani Bovary', 4).
ocena(uzytkownik2, 'Harry Potter i Kamień Filozoficzny', 5).
ocena(uzytkownik2, '1984', 4).
ocena(uzytkownik2, 'Zabić drozda', 3).
ocena(uzytkownik2, 'Cień wiatru', 5).
ocena(uzytkownik2, 'Przeminęło z wiatrem', 4).
ocena(uzytkownik2, 'Wielki Gatsby', 5).
ocena(uzytkownik2, 'Lalka', 3).
ocena(uzytkownik2, 'Moby Dick', 4).
ocena(uzytkownik2, 'Frankenstein', 5).
ocena(uzytkownik2, 'Sherlock Holmes', 3).
ocena(uzytkownik2, 'Wojna i pokój', 5).
ocena(uzytkownik2, 'Odyseja', 4).
ocena(uzytkownik2, 'Złodziejka książek', 2).

ocena(uzytkownik3, 'W pustyni i w puszczy', 3).
ocena(uzytkownik3, 'Hobbit', 5).
ocena(uzytkownik3, 'Pan Tadeusz', 4).
ocena(uzytkownik3, 'Duma i uprzedzenie', 5).
ocena(uzytkownik3, 'Władca pierścieni', 4).
ocena(uzytkownik3, 'Zbrodnia i kara', 3).
ocena(uzytkownik3, 'Mistrz i Małgorzata', 4).
ocena(uzytkownik3, 'Pani Bovary', 5).
ocena(uzytkownik3, 'Harry Potter i Kamień Filozoficzny', 4).
ocena(uzytkownik3, '1984', 5).
ocena(uzytkownik3, 'Zabić drozda', 4).
ocena(uzytkownik3, 'Cień wiatru', 5).
ocena(uzytkownik3, 'Przeminęło z wiatrem', 4).
ocena(uzytkownik3, 'Wielki Gatsby', 3).
ocena(uzytkownik3, 'Lalka', 5).
ocena(uzytkownik3, 'Moby Dick', 3).
ocena(uzytkownik3, 'Frankenstein', 4).
ocena(uzytkownik3, 'Sherlock Holmes', 4).
ocena(uzytkownik3, 'Wojna i pokój', 3).
ocena(uzytkownik3, 'Odyseja', 5).
ocena(uzytkownik3, 'Złodziejka książek', 4).

ocena(uzytkownik4, 'W pustyni i w puszczy', 5).
ocena(uzytkownik4, 'Hobbit', 4).
ocena(uzytkownik4, 'Pan Tadeusz', 4).
ocena(uzytkownik4, 'Duma i uprzedzenie', 4).
ocena(uzytkownik4, 'Władca pierścieni', 4).
ocena(uzytkownik4, 'Zbrodnia i kara', 4).
ocena(uzytkownik4, 'Mistrz i Małgorzata', 4).
ocena(uzytkownik4, 'Pani Bovary', 4).
ocena(uzytkownik4, 'Harry Potter i Kamień Filozoficzny', 4).
ocena(uzytkownik4, '1984', 4).
ocena(uzytkownik4, 'Zabić drozda', 4).
ocena(uzytkownik4, 'Cień wiatru', 4).
ocena(uzytkownik4, 'Przeminęło z wiatrem', 4).
ocena(uzytkownik4, 'Wielki Gatsby', 4).
ocena(uzytkownik4, 'Lalka', 4).
ocena(uzytkownik4, 'Moby Dick', 4).
ocena(uzytkownik4, 'Frankenstein', 4).
ocena(uzytkownik4, 'Sherlock Holmes', 4).
ocena(uzytkownik4, 'Wojna i pokój', 4).
ocena(uzytkownik4, 'Odyseja', 4).
ocena(uzytkownik4, 'Złodziejka książek', 4).

ocena(uzytkownik5, 'W pustyni i w puszczy', 5).
ocena(uzytkownik5, 'Hobbit', 5).
ocena(uzytkownik5, 'Pan Tadeusz', 5).
ocena(uzytkownik5, 'Duma i uprzedzenie', 5).
ocena(uzytkownik5, 'Władca pierścieni', 5).
ocena(uzytkownik5, 'Zbrodnia i kara', 5).
ocena(uzytkownik5, 'Mistrz i Małgorzata', 5).
ocena(uzytkownik5, 'Pani Bovary', 5).
ocena(uzytkownik5, 'Harry Potter i Kamień Filozoficzny', 5).
ocena(uzytkownik5, '1984', 5).
ocena(uzytkownik5, 'Zabić drozda', 5).
ocena(uzytkownik5, 'Cień wiatru', 5).
ocena(uzytkownik5, 'Przeminęło z wiatrem', 5).
ocena(uzytkownik5, 'Wielki Gatsby', 5).
ocena(uzytkownik5, 'Lalka', 5).
ocena(uzytkownik5, 'Moby Dick', 5).
ocena(uzytkownik5, 'Frankenstein', 5).
ocena(uzytkownik5, 'Sherlock Holmes', 5).
ocena(uzytkownik5, 'Wojna i pokój', 5).
ocena(uzytkownik5, 'Odyseja', 5).
ocena(uzytkownik5, 'Złodziejka książek', 5).

% Fakty dotyczące preferencji
preferencje(uzytkownik1, fantasy).
preferencje(uzytkownik1, romans).
preferencje(uzytkownik1, kryminał).

preferencje(uzytkownik2, fantasy).
preferencje(uzytkownik2, kryminał).
preferencje(uzytkownik2, dramat).

preferencje(uzytkownik3, romans).
preferencje(uzytkownik3, literatura_klasyczna).
preferencje(uzytkownik3, powieść_społeczna).

preferencje(uzytkownik4, fantasy).
preferencje(uzytkownik4, kryminał).
preferencje(uzytkownik4, dramat).

preferencje(uzytkownik5, fantasy).
preferencje(uzytkownik5, romans).
preferencje(uzytkownik5, literatura_klasyczna).

% Reguła do dynamicznego zarządzania ocenami
dodaj_ocene(Uzytkownik, Ksiazka, Ocena) :-
    assertz(ocena(Uzytkownik, Ksiazka, Ocena)).

usun_ocene(Uzytkownik, Ksiazka) :-
    retract(ocena(Uzytkownik, Ksiazka, _)).

% Zaktualizowanie oceny książki
zaktualizuj_ocene(Uzytkownik, Ksiazka, NowaOcena) :-
    usun_ocene(Uzytkownik, Ksiazka),
    dodaj_ocene(Uzytkownik, Ksiazka, NowaOcena).

% Reguła polecane_ksiazki/2
polecane_ksiazki(Uzytkownik, Gatunek) :-
    % Zbieranie książek, które pasują do gatunku i mają ocenę >= 4
    findall(Ksiazka,
            (ksiazka(Ksiazka, _, Gatunek),
             ocena(Uzytkownik, Ksiazka, Ocena),
             Ocena >= 4),
            Ksiazek),
    % Wyświetlanie wyników
    write('Polecane książki dla użytkownika '),
    write(Uzytkownik),
    write(' w gatunku '),
    write(Gatunek),
    write(': '),
    write(Ksiazek), nl.

% Polecane książki na podstawie preferencji użytkownika
polecane_ksiazki_na_podstawie_preferencji(Uzytkownik) :-
    % Zbieranie książek, które pasują do preferencji i mają ocenę >= 4
    findall(Ksiazka,
            (preferencje(Uzytkownik, Gatunek),
             ksiazka(Ksiazka, _, Gatunek),
             ocena(Uzytkownik, Ksiazka, Ocena),
             Ocena >= 4),
            Ksiazek),
    % Wyświetlanie wyników
    write('Polecane książki dla użytkownika '),
    write(Uzytkownik),
    write(' na podstawie preferencji: '),
    nl,
    maplist(writeln, Ksiazek).  % Wyświetlanie książek w nowych liniach

% Średnia ocena książki
srednia_ocena(Ksiazka, SredniaOcena) :-
    findall(Ocena, ocena(_, Ksiazka, Ocena), Oceny),
    length(Oceny, L),
    L > 0,  % Upewnij się, że książka ma co najmniej jedną ocenę
    sum_list(Oceny, Suma),
    SredniaOcena is Suma / L.

% Polecane książki na podstawie podobnych ocen
polecane_na_podstawie_ocen(Uzytkownik) :-
    findall(Ksiazka,
            (ocena(Uzytkownik, Ksiazka, Ocena),
             Ocena >= 4,
             ksiazka(Ksiazka, _, _)),
            Ksiazek),
    write('Polecane książki dla użytkownika '),
    write(Uzytkownik),
    write(' na podstawie ocen: '),
    nl,
    maplist(writeln, Ksiazek).

% Książki według gatunku i ocen
ksiazki_po_ocenie_i_gatunku(Gatunek) :-
    findall(Ksiazka,
            (ksiazka(Ksiazka, _, Gatunek),
             ocena(_, Ksiazka, Ocena),
             Ocena >= 4),
            Ksiazek),
    write('Książki w gatunku '),
    write(Gatunek),
    write(' z oceną >= 4: '),
    nl,
    maplist(writeln, Ksiazek).

# %% [markdown]
# #**Przykładowe zapytania**

# %% [markdown]
# ##**Zapytania do reguł związanych z dynamicznym zarządzaniem ocenami:**
#
# ##**1. Dodanie nowej oceny:**
# ```
# ?- dodaj_ocene(uzytkownik2, '1984', 5).
# ```
# ###**Wynik:**
# ```
# True
# ```
# ##**2. Usunięcie oceny:**
# ```
# ?- usun_ocene(uzytkownik1, 'Hobbit').
# ```
# ###**Wynik:**
# ```
# True
# ```
# ##**3. Zaktualizowanie oceny:**
# ```
# ?- zaktualizuj_ocene(uzytkownik1, 'Pan Tadeusz', 5).
# ```
# ###**Wynik:**
# ```
# True
# ```
# ##**4. Zapytania do reguły polecane_ksiazki/2:**
# ```
# ?- polecane_ksiazki(uzytkownik1, fantasy).
# ```
# ###**Wynik:**
# ```
# Polecane książki dla użytkownika uzytkownik1 w gatunku fantasy: [Hobbit, Władca pierścieni, Mistrz i Małgorzata, Harry Potter i Kamień Filozoficzny]
# ```
# ##**5. Zapytania do reguły polecane_ksiazki_na_podstawie_preferencji/1:**
# ```
# ?- polecane_ksiazki_na_podstawie_preferencji(uzytkownik2).
# ```
# ###**Wynik:**
# ```
# Polecane książki dla użytkownika uzytkownik2 na podstawie preferencji:
# Hobbit
# Władca pierścieni
# Harry Potter i Kamień Filozoficzny
# Zbrodnia i kara
# ```
# ```
# True
# ```
#
# ##**6. Zapytania do reguły srednia_ocena/2:**
# ```
# ?- srednia_ocena('W pustyni i w puszczy', SredniaOcena).
# ```
# ###**Wynik:**
# ```
# SredniaOcena = 4.4
# ```
# ##**7. Zapytania do reguły polecane_na_podstawie_ocen/1:**
# ```
# ?- polecane_na_podstawie_ocen(uzytkownik4).
# ```
# ###**Wynik:**
# ```
# Polecane książki dla użytkownika uzytkownik4 na podstawie ocen:
# W pustyni i w puszczy
# Hobbit
# Pan Tadeusz
# Duma i uprzedzenie
# Władca pierścieni
# Zbrodnia i kara
# Mistrz i Małgorzata
# Pani Bovary
# Harry Potter i Kamień Filozoficzny
# 1984
# Zabić drozda
# Cień wiatru
# Przeminęło z wiatrem
# Wielki Gatsby
# Lalka
# Moby Dick
# Frankenstein
# Sherlock Holmes
# Wojna i pokój
# Odyseja
# Złodziejka książek
# ```
# ```
# True
# ```
#
# ##**8. Zapytania do reguły ksiazki_po_ocenie_i_gatunku/1:**
# ```
# ?- ksiazki_po_ocenie_i_gatunku(fantasy).
# ```
# ###**Wynik:**
# ```
# Książki w gatunku fantasy z oceną >= 4:
# Hobbit
# Hobbit
# Hobbit
# Hobbit
# Hobbit
# Władca pierścieni
# Władca pierścieni
# Władca pierścieni
# Władca pierścieni
# Władca pierścieni
# Mistrz i Małgorzata
# Mistrz i Małgorzata
# Mistrz i Małgorzata
# Mistrz i Małgorzata
# Harry Potter i Kamień Filozoficzny
# Harry Potter i Kamień Filozoficzny
# Harry Potter i Kamień Filozoficzny
# Harry Potter i Kamień Filozoficzny
# Harry Potter i Kamień Filozoficzny
# ```
# ```
# True
# ```

# %% [markdown]
# #Wytłumaczenie:

# %% [markdown]
# ##**Zapytania do reguł związanych z dynamicznym zarządzaniem ocenami:**
# ## **1. Dodanie nowej oceny**
# ```
# dodaj_ocene(Uzytkownik, Ksiazka, Ocena) :-
#     assertz(ocena(Uzytkownik, Ksiazka, Ocena)).
# ```
# ###**Opis:**
#
# - Reguła `dodaj_ocene/3` umożliwia dodanie nowej oceny do bazy danych.
# - `assertz/1` służy do dynamicznego dodawania faktu do bazy danych.
# - `ocena(Uzytkownik, Ksiazka, Ocena)` tworzy fakt o ocenach książek przez użytkowników, gdzie `Uzytkownik` to osoba oceniająca, `Ksiazka` to tytuł książki, a `Ocena` to jej wartość *(np. 5)*.
# - Kiedy wywołasz `dodaj_ocene(uzytkownik2, '1984', 5)`, fakt `ocena(uzytkownik2, '1984', 5)` zostanie dodany do bazy danych.
#
# ##**2. Usunięcie oceny**
#
#
# ```
# usun_ocene(Uzytkownik, Ksiazka) :-
#     retract(ocena(Uzytkownik, Ksiazka, _)).
# ```
# ###**Opis:**
# - Reguła `usun_ocene/2` umożliwia usunięcie oceny danej książki przez użytkownika.
# - `retract/1` służy do usuwania faktu z bazy danych, który pasuje do wzorca.
# - Wzorzec `ocena(Uzytkownik, Ksiazka, _)` oznacza, że chcemy usunąć ocenę dla książki `Ksiazka` wystawioną przez użytkownika `Uzytkownik` bez względu na wartość oceny (dlatego `_` oznacza dowolną wartość).
# - Na przykład, wywołując `usun_ocene(uzytkownik1, 'Hobbit')`, usuwa się ocenę książki "Hobbit" wystawioną przez `uzytkownik1`.
#
# ##**3. Zaktualizowanie oceny**
#
#
# ```
# zaktualizuj_ocene(Uzytkownik, Ksiazka, NowaOcena) :-
#     usun_ocene(Uzytkownik, Ksiazka),
#     dodaj_ocene(Uzytkownik, Ksiazka, NowaOcena).
# ```
# ###**Opis:**
# - Reguła `zaktualizuj_ocene/3` najpierw usuwa starą ocenę książki, a potem dodaje nową.
# - Używa najpierw reguły `usun_ocene/2` do usunięcia istniejącej oceny, a następnie reguły `dodaj_ocene/3` do dodania nowej oceny.
# - Na przykład, wywołując `zaktualizuj_ocene(uzytkownik1, 'Pan Tadeusz', 5)`, usuwasz starą ocenę książki "Pan Tadeusz" i dodajesz ocenę 5.
#
# ##**4. Zapytania do reguły polecane_ksiazki**
#
#
# ```
# polecane_ksiazki(Uzytkownik, Gatunek) :-
#     findall(Ksiazka,
#             (ksiazka(Ksiazka, _, Gatunek),
#              ocena(Uzytkownik, Ksiazka, Ocena),
#              Ocena >= 4),
#             Ksiazek),
#     write('Polecane książki dla użytkownika '),
#     write(Uzytkownik),
#     write(' w gatunku '),
#     write(Gatunek),
#     write(': '),
#     write(Ksiazek), nl.
# ```
#
# ###**Opis:**
# - Reguła `polecane_ksiazki/2` znajduje książki w określonym gatunku, które użytkownik ocenił na co najmniej 4.
# - `findall/3` zbiera wszystkie książki (`Ksiazka`), które spełniają warunki:
#   - Książka należy do gatunku `Gatunek`.
#   - Użytkownik ocenił ją na co najmniej 4.
#
# - Następnie, wynik jest wyświetlany na ekranie przy pomocy `write/1`, prezentując listę książek.
# - Na przykład, `polecane_ksiazki(uzytkownik1, fantasy)` wyświetli książki w gatunku fantasy ocenione przez `uzytkownik1` na co najmniej 4.
#
# ##**5. Zapytania do reguły polecane_ksiazki_na_podstawie_preferencji**
#
# ```
# polecane_ksiazki_na_podstawie_preferencji(Uzytkownik) :-
#     findall(Ksiazka,
#             (preferencje(Uzytkownik, Gatunek),
#              ksiazka(Ksiazka, _, Gatunek),
#              ocena(Uzytkownik, Ksiazka, Ocena),
#              Ocena >= 4),
#             Ksiazek),
#     write('Polecane książki dla użytkownika '),
#     write(Uzytkownik),
#     write(' na podstawie preferencji: '),
#     nl,
#     maplist(writeln, Ksiazek).
# ```
# ###**Opis:**
# - Reguła `polecane_ksiazki_na_podstawie_preferencji/1` zbiera książki pasujące do preferencji użytkownika i ocenione przez niego na co najmniej 4.
# - `findall/3` zbiera książki, które:
#   - Pasują do gatunku preferowanego przez użytkownika (określonego w fakcie `preferencje/2`).
#   - Użytkownik ocenił je na co najmniej 4.
# - Wynik jest wyświetlany przy użyciu `write/1` oraz `maplist(writeln, Ksiazek)` do wyświetlania książek w nowych liniach.
# - Na przykład, `polecane_ksiazki_na_podstawie_preferencji(uzytkownik2)` wyświetli książki, które użytkownik `uzytkownik2` lubi i ocenił na co najmniej 4.
# ##**6. Zapytania do reguły srednia_ocena**
#
#
# ```
# srednia_ocena(Ksiazka, SredniaOcena) :-
#     findall(Ocena, ocena(_, Ksiazka, Ocena), Oceny),
#     length(Oceny, L),
#     L > 0,
#     sum_list(Oceny, Suma),
#     SredniaOcena is Suma / L.
# ```
#
# ###**Opis:**
# - Reguła `srednia_ocena/2` oblicza średnią ocenę książki na podstawie ocen, które zostały jej przypisane.
# - `findall/3` zbiera wszystkie oceny książki `Ksiazka` w liście `Oceny`.
# - `length/2` liczy liczbę ocen (przechowywaną w zmiennej `L`), a `sum_list/2` sumuje je.
# - Średnia ocena jest obliczana jako suma ocen podzielona przez liczbę ocen.
# - Na przykład, `srednia_ocena('W pustyni i w puszczy', SredniaOcena)` zwróci średnią ocenę książki "W pustyni i w puszczy".
#
# ##**7. Zapytania do reguły polecane_na_podstawie_ocen**
#
#
# ```
# polecane_na_podstawie_ocen(Uzytkownik) :-
#     findall(Ksiazka,
#             (ocena(Uzytkownik, Ksiazka, Ocena),
#              Ocena >= 4,
#              ksiazka(Ksiazka, _, _)),
#             Ksiazek),
#     write('Polecane książki dla użytkownika '),
#     write(Uzytkownik),
#     write(' na podstawie ocen: '),
#     nl,
#     maplist(writeln, Ksiazek).
# ```
#
# ###**Opis:**
# - Reguła `polecane_na_podstawie_ocen/1` zbiera książki, które użytkownik ocenił na co najmniej 4.
# - `findall/3` zbiera książki, które użytkownik ocenił na co najmniej 4, a `ksiazka/3` zapewnia, że książka istnieje w bazie danych.
# - Wynik jest wyświetlany na ekranie przy użyciu `write/1` i `maplist(writeln, Ksiazek)`.
#
# ##**8. Zapytania do reguły ksiazki_po_ocenie_i_gatunku**
# ```
# ksiazki_po_ocenie_i_gatunku(Gatunek) :-
#     findall(Ksiazka,
#             (ksiazka(Ksiazka, _, Gatunek),
#              ocena(_, Ksiazka, Ocena),
#              Ocena >= 4),
#             Ksiazek),
#     write('Książki w gatunku '),
#     write(Gatunek),
#     write(' z oceną >= 4: '),
#     nl,
#     maplist(writeln, Ksiazek).
# ```
# ###**Opis:**
# - Reguła `ksiazki_po_ocenie_i_gatunku/1` zbiera książki w określonym gatunku, które mają ocenę co najmniej 4.
# - `findall/3` wyszukuje książki w danym gatunku (`Gatunek`), a także sprawdza, czy zostały ocenione na co najmniej 4.
# -Wynik jest wyświetlany na ekranie przy użyciu `write/1` i `maplist(writeln, Ksiazek)`.
